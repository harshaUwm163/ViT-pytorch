# %%
import torch
from utils.construct_tff import construct_real_tff
import matplotlib.pyplot as plt

# %%
k_attn = 64
l_attn = 384
n_attn = 768
tffs = construct_real_tff(k_attn, l_attn // 2, n_attn // 2)
frame_cat = tffs.view(-1, n_attn)

# %%
autoCorr = tffs[0] @ tffs[0].permute(1,0)
plt.gray()
plt.imshow(autoCorr)
plt.show()

# %%
autoCorr = tffs[0] @ tffs[1].permute(1,0)
plt.gray()
plt.imshow(autoCorr)
plt.show()

# %%
autoCorr = tffs[0] @ tffs[1].permute(1,0)
plt.gray()
plt.imshow(autoCorr)
plt.show()
